# %% [markdown]
# # DataFrame Basics I

# %% [markdown]
# ### Read file

# %%
import pandas as pd

# %%
titanic_df = pd.read_csv('titanic.csv')

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# ### Read files from another folder

# %%
iris_df_1 = pd.read_csv('../_Course_Materials_-_Nov_23_-_Initial/iris.csv')

# %%
iris_df_1
# Out:
#      sepal_length   sepal_width   petal_length   petal_width           class
# 0             5.1           3.5            1.4           0.2     Iris-setosa
# 1             4.9           3.0            1.4           0.2     Iris-setosa
# 2             4.7           3.2            1.3           0.2     Iris-setosa
# 3             4.6           3.1            1.5           0.2     Iris-setosa
# 4             5.0           3.6            1.4           0.2     Iris-setosa
# ..            ...           ...            ...           ...             ...
# 145           6.7           3.0            5.2           2.3  Iris-virginica
# 146           6.3           2.5            5.0           1.9  Iris-virginica
# 147           6.5           3.0            5.2           2.0  Iris-virginica
# 148           6.2           3.4            5.4           2.3  Iris-virginica
# 149           5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_df_2 = pd.read_csv(r'C:\_Workspace\forJobApplications\Udemy-The-Complete-Pandas-Bootcamp\_Course_Materials_-_Nov_23_-_Initial\iris.csv')

# %%
iris_df_2
# Out:
#      sepal_length   sepal_width   petal_length   petal_width           class
# 0             5.1           3.5            1.4           0.2     Iris-setosa
# 1             4.9           3.0            1.4           0.2     Iris-setosa
# 2             4.7           3.2            1.3           0.2     Iris-setosa
# 3             4.6           3.1            1.5           0.2     Iris-setosa
# 4             5.0           3.6            1.4           0.2     Iris-setosa
# ..            ...           ...            ...           ...             ...
# 145           6.7           3.0            5.2           2.3  Iris-virginica
# 146           6.3           2.5            5.0           1.9  Iris-virginica
# 147           6.5           3.0            5.2           2.0  Iris-virginica
# 148           6.2           3.4            5.4           2.3  Iris-virginica
# 149           5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Display functions and **hail()** & **tail()** functions

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
pd.options.display.min_rows = 20

# %%
iris_df_2
# Out:
#      sepal_length   sepal_width   petal_length   petal_width           class
# 0             5.1           3.5            1.4           0.2     Iris-setosa
# 1             4.9           3.0            1.4           0.2     Iris-setosa
# 2             4.7           3.2            1.3           0.2     Iris-setosa
# 3             4.6           3.1            1.5           0.2     Iris-setosa
# 4             5.0           3.6            1.4           0.2     Iris-setosa
# 5             5.4           3.9            1.7           0.4     Iris-setosa
# 6             4.6           3.4            1.4           0.3     Iris-setosa
# 7             5.0           3.4            1.5           0.2     Iris-setosa
# 8             4.4           2.9            1.4           0.2     Iris-setosa
# 9             4.9           3.1            1.5           0.1     Iris-setosa
# ..            ...           ...            ...           ...             ...
# ...

# %%
titanic_df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
titanic_df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %% [markdown]
# ### First data inspection

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic_df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# To see description of non-numeric columns:

# %%
titanic_df.describe(include = "O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# ### Built-in functions, attributes and methods with pandas

# %%
type(titanic_df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(titanic_df)
# Out:
# 891

# %%
round(titanic_df, 0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# 5           0       3    male   NaN      0      0   8.0        Q  NaN
# 6           0       1    male  54.0      0      0  52.0        S    E
# 7           0       3    male   2.0      3      1  21.0        S  NaN
# 8           1       3  female  27.0      0      2  11.0        S  NaN
# 9           1       2  female  14.0      1      0  30.0        C  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 881         0       3    male  33.0      0      0   8.0        S  NaN
# ...

# %% [markdown]
# ##### **Attributes**

# %%
titanic_df.shape
# Out:
# (891, 9)

# %%
titanic_df.size
# Out:
# 8019

# %%
titanic_df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic_df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# ##### **Methods**

# %%
titanic_df.head(n = 2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic_df.min(numeric_only = True)
# Out:
# survived    0.00
# pclass      1.00
# age         0.42
# sibsp       0.00
# parch       0.00
# fare        0.00
# dtype: float64

# %% [markdown]
# ##### **Method chaning**

# %%
titanic_df.mean(numeric_only = True)
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic_df.mean(numeric_only = True).sort_values()
# Out:
# parch        0.381594
# survived     0.383838
# sibsp        0.523008
# pclass       2.308642
# age         29.699118
# fare        32.204208
# dtype: float64

# %%
titanic_df.mean(numeric_only = True).sort_values().head(2)
# Out:
# parch       0.381594
# survived    0.383838
# dtype: float64

# %% [markdown]
# ### TAB Completion and Tooltip

# %%
titanic_df.sort_values(by = 'age', ascending = False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# 672         0       2    male  70.0      0      0  10.5000        S  NaN
# 745         0       1    male  70.0      1      1  71.0000        S    B
# 33          0       2    male  66.0      0      0  10.5000        S  NaN
# 54          0       1    male  65.0      0      1  61.9792        C    B
# 280         0       3    male  65.0      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 832         0       3    male   NaN      0      0   7.2292        C  NaN
# ...

# %% [markdown]
# ### Seelcting columns

# %%
age_column = titanic_df["age"]

# %%
age_column
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
#        ...
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(age_column)
# Out:
# pandas.core.series.Series

# %% [markdown]
# But mind the following:

# %%
age_column_2 = titanic_df[["age"]]

# %%
age_column_2
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# ..    ...
# 881  33.0
# 882  22.0
# 883  28.0
# 884  25.0
# 885  39.0
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
type(age_column_2)
# Out:
# pandas.core.frame.DataFrame

# %%
some_columns = titanic_df[["age", "sex"]]

# %%
some_columns
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# 5     NaN    male
# 6    54.0    male
# 7     2.0    male
# 8    27.0  female
# 9    14.0  female
# ..    ...     ...
# 881  33.0    male
# 882  22.0  female
# 883  28.0    male
# 884  25.0    male
# 885  39.0  female
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(some_columns)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Seelcting columns using dot notation

# %%
age_column_3 = titanic_df.age

# %%
age_column_3
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
#        ...
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
age_column_3.equals(age_column)
# Out:
# True

# %% [markdown]
# ## Position-based Indexing

# %%
summer_df = pd.read_csv("summer.csv", index_col = 'Athlete')

# %%
summer_df
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto              1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios             1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis            1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon            1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis              1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# NEUMANN, Paul                 1896  Athens   Aquatics             Swimming
# ...                            ...     ...        ...                  ...
# ...

# %%
summer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer_df.describe()
# Out:
#                Year
# count  31165.000000
# mean    1970.482785
# std       33.158416
# min     1896.000000
# 25%     1948.000000
# 50%     1980.000000
# 75%     2000.000000
# max     2012.000000

# %%
summer_df.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
summer_df.iloc[[0]]
# Out:
#                Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
#
#                         Event Medal
# Athlete
# HAJOS, Alfred  100M Freestyle  Gold

# %%
summer_df.iloc[1:3,]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
summer_df.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
summer_df.iloc[[1, 2, 3]]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
summer_df.iloc[1:4]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
summer_df.iloc[-5:]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men  Wg 96 KG  Bronze

# %%
summer_df.iloc[:]
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto              1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios             1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis            1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon            1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis              1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# NEUMANN, Paul                 1896  Athens   Aquatics             Swimming
# ...                            ...     ...        ...                  ...
# ...

# %% [markdown]
# ## Slicing with position-basd indices

# %%
summer_df.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer_df.iloc[0, 4]
# Out:
# 'HUN'

# %%
summer_df.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
summer_df.iloc[0, :3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
summer_df.iloc[0, [0, 4, 6]]
# Out:
# Year                 1896
# Country               HUN
# Event      100M Freestyle
# Name: HAJOS, Alfred, dtype: object

# %%
summer_df.iloc[0:6, [0, 4, 6]]
# Out:
#                        Year Country                       Event
# Athlete
# HAJOS, Alfred          1896     HUN              100M Freestyle
# HERSCHMANN, Otto       1896     AUT              100M Freestyle
# DRIVAS, Dimitrios      1896     GRE  100M Freestyle For Sailors
# MALOKINIS, Ioannis     1896     GRE  100M Freestyle For Sailors
# CHASAPIS, Spiridon     1896     GRE  100M Freestyle For Sailors
# CHOROPHAS, Efstathios  1896     GRE             1200M Freestyle

# %%
summer_df.iloc[:, 0]
# Out:
# Athlete
# HAJOS, Alfred                   1896
# HERSCHMANN, Otto                1896
# DRIVAS, Dimitrios               1896
# MALOKINIS, Ioannis              1896
# CHASAPIS, Spiridon              1896
# CHOROPHAS, Efstathios           1896
# HAJOS, Alfred                   1896
# ANDREOU, Joannis                1896
# CHOROPHAS, Efstathios           1896
# NEUMANN, Paul                   1896
#                                 ...
# AHMADOV, Emin                   2012
# KAZAKEVIC, Aleksandr            2012
# KHUGAEV, Alan                   2012
# EBRAHIM, Karam Mohamed Gaber    2012
# GAJIYEV, Danyal                 2012
# JANIKOWSKI, Damian              2012
# REZAEI, Ghasem Gholamreza       2012
# TOTROV, Rustam                  2012
# ALEKSANYAN, Artur               2012
# LIDBERG, Jimmy                  2012
# Name: Year, Length: 31165, dtype: int64

# %%
summer_df.iloc[:, 0].equals(summer_df['Year'])
# Out:
# True

# %%
summer_df.iloc[0, 0]
# Out:
# 1896

# %% [markdown]
# ## Label-based Indexing

# %%
summer_df.loc['DRIVAS, Dimitrios']
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer_df.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %% [markdown]
# ## Slicing with label-based indices

# %%
summer_df.loc['PHELPS, Michael', 'Medal']
# Out:
# Athlete
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# Name: Medal, dtype: object

# %%
summer_df.loc['PHELPS, Michael', ['Medal', 'Event']]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# ...

# %%
summer_df.loc[:, 'Event']
# Out:
# Athlete
# HAJOS, Alfred                               100M Freestyle
# HERSCHMANN, Otto                            100M Freestyle
# DRIVAS, Dimitrios               100M Freestyle For Sailors
# MALOKINIS, Ioannis              100M Freestyle For Sailors
# CHASAPIS, Spiridon              100M Freestyle For Sailors
# CHOROPHAS, Efstathios                      1200M Freestyle
# HAJOS, Alfred                              1200M Freestyle
# ANDREOU, Joannis                           1200M Freestyle
# CHOROPHAS, Efstathios                       400M Freestyle
# NEUMANN, Paul                               400M Freestyle
#                                            ...
# AHMADOV, Emin                                     Wg 74 KG
# KAZAKEVIC, Aleksandr                              Wg 74 KG
# KHUGAEV, Alan                                     Wg 84 KG
# EBRAHIM, Karam Mohamed Gaber                      Wg 84 KG
# GAJIYEV, Danyal                                   Wg 84 KG
# ...

# %%
summer_df.loc[summer_df['Country'] == 'BUL']
# Out:
#                              Year                   City          Sport  \
# Athlete
# NIKOLOV, Boris Georgiev      1952               Helsinki         Boxing
# DIEV, Todor Nedyalkov        1956  Melbourne / Stockholm       Football
# KOLEV, Ivan Petkov           1956  Melbourne / Stockholm       Football
# KOVATCHEV, Nikolai Dimitrov  1956  Melbourne / Stockholm       Football
# MANOLOV, Manol Tomov         1956  Melbourne / Stockholm       Football
# NAYDENOV, Georghi Spirov     1956  Melbourne / Stockholm       Football
# NIKOLOV, Guergui Dimitrov    1956  Melbourne / Stockholm       Football
# NIKOLOV, Miltcho Goranov     1956  Melbourne / Stockholm       Football
# PANAYOTOV, Panayot Mitov     1956  Melbourne / Stockholm       Football
# RAKAROV, Kirill Manolov      1956  Melbourne / Stockholm       Football
# ...                           ...                    ...            ...
# CHOLAKOV, Velichko           2004                 Athens  Weightlifting
# ...

# %% [markdown]
# ## Indexing and slicing using **reindex()**

# %%
summer_df_2 = pd.read_csv('summer.csv')

# %%
summer_df_2.loc[[0, 5, 30000], ['Athlete', 'Medal']]
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze

# %%
summer_df_2.reindex(index = [0, 5, 30000, 40000], columns = ['Athlete', 'Medal'])
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze
# 40000                    NaN     NaN

# %%
summer_df_2.reindex(index = [0, 5, 30000, 40000], columns = ['Athlete', 'Age', 'Medal'])
# Out:
#                      Athlete  Age   Medal
# 0              HAJOS, Alfred  NaN    Gold
# 5      CHOROPHAS, Efstathios  NaN  Bronze
# 30000       PAUTARAN, Maryna  NaN  Bronze
# 40000                    NaN  NaN     NaN

# %%
summer_df.reindex(index = ['PHELPS, Michael'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 summer_df.reindex(index = ['PHELPS, Michael'])
#
# File ~\.conda\envs\udemy-pandas-bootcamp\Lib\site-packages\pandas\core\frame.py:5141, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5122 @doc(
#    5123     NDFrame.reindex,
#    5124     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5139     tolerance=None,
#    5140 ) -> DataFrame:
# -> 5141     return super().reindex(
#    5142         labels=labels,
#    5143         index=index,
#    5144         columns=columns,
#    5145         axis=axis,
#    5146         method=method,
#    5147         copy=copy,
#    5148         level=level,
#    5149         fill_value=fill_value,
#    5150         limit=limit,
#    5151         tolerance=tolerance,
#    5152     )
#
# ...

# %% [markdown]
# ## Advanced indexing and slicing

# %%
rows = list(range(5)) + [354, 765]
rows
small_data_1 = summer_df.iloc[rows]
small_data_1
# Out:
#                     Year      City       Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896    Athens    Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896    Athens    Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896    Athens    Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896    Athens    Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896    Athens    Aquatics   Swimming     GRE    Men
# DE BELLEGARDE       1900     Paris  Equestrian    Jumping     FRA    Men
# CORAY, Albert       1904  St Louis   Athletics  Athletics     ZZX    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver
# ...

# %%
cols = summer_df.columns[:3].to_list() + ['Gender', 'Event']
small_data_2 = summer_df.loc[:, cols]
small_data_2
# Out:
#                               Year    City      Sport Gender  \
# Athlete
# HAJOS, Alfred                 1896  Athens   Aquatics    Men
# HERSCHMANN, Otto              1896  Athens   Aquatics    Men
# DRIVAS, Dimitrios             1896  Athens   Aquatics    Men
# MALOKINIS, Ioannis            1896  Athens   Aquatics    Men
# CHASAPIS, Spiridon            1896  Athens   Aquatics    Men
# CHOROPHAS, Efstathios         1896  Athens   Aquatics    Men
# HAJOS, Alfred                 1896  Athens   Aquatics    Men
# ANDREOU, Joannis              1896  Athens   Aquatics    Men
# CHOROPHAS, Efstathios         1896  Athens   Aquatics    Men
# NEUMANN, Paul                 1896  Athens   Aquatics    Men
# ...                            ...     ...        ...    ...
# AHMADOV, Emin                 2012  London  Wrestling    Men
# KAZAKEVIC, Aleksandr          2012  London  Wrestling    Men
# KHUGAEV, Alan                 2012  London  Wrestling    Men
# ...

# %%
small_data_3 = summer_df_2.loc[[200, 300], ['Athlete', 'Medal']]
small_data_3
# Out:
#                       Athlete   Medal
# 200               KEMP, Peter    Gold
# 300  SHELDON, Lewis Pendleton  Bronze

# %%
cols_2 = summer_df.columns[[4, 6]]
small_data_4 = summer_df.loc['PHELPS, Michael', cols_2]
small_data_4
# Out:
#                 Country                   Event
# Athlete
# PHELPS, Michael     USA          100M Butterfly
# PHELPS, Michael     USA          200M Butterfly
# PHELPS, Michael     USA          200M Freestyle
# PHELPS, Michael     USA  200M Individual Medley
# PHELPS, Michael     USA  400M Individual Medley
# PHELPS, Michael     USA  4X100M Freestyle Relay
# PHELPS, Michael     USA     4X100M Medley Relay
# PHELPS, Michael     USA  4X200M Freestyle Relay
# PHELPS, Michael     USA          100M Butterfly
# PHELPS, Michael     USA          200M Butterfly
# PHELPS, Michael     USA          200M Freestyle
# PHELPS, Michael     USA  200M Individual Medley
# PHELPS, Michael     USA  400M Individual Medley
# PHELPS, Michael     USA  4X100M Freestyle Relay
# PHELPS, Michael     USA     4X100M Medley Relay
# PHELPS, Michael     USA  4X200M Freestyle Relay
# PHELPS, Michael     USA          100M Butterfly
# PHELPS, Michael     USA          200M Butterfly
# ...

# %%
small_data_5 = summer_df.ix['PHELPS, Michael', cols_2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8992\1363995229.py in ?()
# ----> 1 small_data_5 = summer_df.ix['PHELPS, Michael', cols_2]
#
# ~\.conda\envs\udemy-pandas-bootcamp\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
